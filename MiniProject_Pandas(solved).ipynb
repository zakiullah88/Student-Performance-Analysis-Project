# %% [markdown]
# # **PANDAS MINI PROJECT**

# %% [markdown]
# You are a data analyst at a university tasked with analyzing the grades of students in a course. Your goal is to provide insights into the performance of students, identify patterns, and make recommendations for improving student outcomes. You will use Python, Pandas, and Numpy to load, clean, and analyze the data where appropriate

# %%
#load the libraries
import pandas as pd
import numpy as np

# %%
#load the roster file and display first 5 rows
roster = pd.read_csv('/content/roster - roster.csv.xls')

netid = roster[['NetID','ID']]

# %% [markdown]
# Eh? This is not the data that we want :( We want to have it more modified.

# %% [markdown]
#   We want the 'roster' to be something else! How though:
#
#   We want **NetID**, **Email Address** and **Section** but somehow different:
#
#   1. NetID: make the each string in lowercase and have it set as an index.
#   2. Email Address: have the string in lowercase
#
#   and after that, have these 3 columns display in a dataframe.

# %%
#data pre-processing
roster['NetID'] = roster['NetID'].str.lower()
roster.set_index('NetID', inplace=True)
roster['Email Address'] = roster['Email Address'].str.lower()

# %% [markdown]
# ### **Load the homework and exam data**

# %%
#load the hw_exam_grades and display first 5 rows
hw_exam_grades = pd.read_csv('/content/hw_exam_grades (1) - hw_exam_grades (1).csv.xls')
hw_exam_grades.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# 1    2019-09-05 08:56:02-07:00          78  ...
# 2    2019-09-05 08:56:02-07:00          66  ...
# 3    2019-09-05 08:56:02-07:00          74  ...
# 4    2019-09-05 08:56:02-07:00          77  ...
#
#    Homework 10 - Submission Time Exam 1  Exam 1 - Max Points  \
# 0      2019-10-31 08:56:02-07:00     79                  100
# 1      2019-10-31 08:56:02-07:00     65                  100
# 2      2019-10-31 08:56:02-07:00     65                  100
# 3      2019-10-31 08:56:02-07:00     97                  100
# 4      2019-10-31 08:56:02-07:00     68                  100
#
#     Exam 1 - Submission Time Exam 2  Exam 2 - Max Points  \
# 0  2019-10-08 12:30:07-07:00     63                  100
# 1  2019-10-08 12:30:07-07:00     63                  100
# 2  2019-10-08 12:30:07-07:00     78                  100
# 3  2019-10-08 12:30:07-07:00     97                  100
# 4  2019-10-08 12:30:07-07:00     95                  100
#
#     Exam 2 - Submission Time Exam 3  Exam 3 - Max Points  \
# 0  2019-11-08 12:30:07-07:00     68                  100
# 1  2019-11-08 12:30:07-07:00     90                  100
# 2  2019-11-08 12:30:07-07:00     83                  100
# 3  2019-11-08 12:30:07-07:00     81                  100
# 4  2019-11-08 12:30:07-07:00     88                  100
#
#     Exam 3 - Submission Time
# 0  2019-12-08 12:30:07-07:00
# 1  2019-12-08 12:30:07-07:00
# 2  2019-12-08 12:30:07-07:00
# 3  2019-12-08 12:30:07-07:00
# 4  2019-12-08 12:30:07-07:00
#
# [5 rows x 42 columns]

# %% [markdown]
# The data is not cleaned. We also want to do something different to it.
#
# We want the data to be indexed on the basis of SID and remove all the columns which has the word 'Submission' in it using lambda filter.

# %%
#if you attempt to remove the submissional columns without lambda filter, points will be deducted accordingly.
# hw_exam_grades.set_index('SID', inplace=True)
hw_exam_grades = hw_exam_grades.loc[:, hw_exam_grades.columns.map(lambda x: 'Submission' not in x)]

hw_exam_grades
# Out:
#     First Name   Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0        Aaron      Lester  axl60952        68.0                       80
# 1         Adam      Cooper  amc28428        80.0                       80
# 2         Alec       Curry  axc64717        69.0                       80
# 3    Alexander   Rodriguez  akr14831        50.0                       80
# 4        Amber     Daniels  axd11293        54.0                       80
# ..         ...         ...       ...         ...                      ...
# 145     Travis  Washington  txw75701        64.0                       80
# 146       Troy     Raymond  tbr17292        50.0                       80
# 147   Victoria        Boyd  vkb66346        58.0                       80
# 148    William      Daniel  wad63934        48.0                       80
# 149      Woody     Barrera  wxb12345        55.0                       80
#
#      Homework 2  Homework 2 - Max Points  Homework 3  Homework 3 - Max Points  \
# 0            74                       80          77                       80
# 1            78                       80          78                       80
# 2            76                       80          66                       80
# 3            54                       80          74                       80
# 4            57                       80          77                       80
# ..          ...                      ...         ...                      ...
# 145          67                       80          56                       80
# 146          59                       80          79                       80
# 147          61                       80          75                       80
# 148          60                       80          72                       80
# 149          62                       80          73                       80
#
#      Homework 4  ...  Homework 9  Homework 9 - Max Points  Homework 10  \
# 0            89  ...          42                       60           41
# 1            87  ...          45                       60           53
# 2            87  ...          58                       60           42
# 3            75  ...          38                       60           47
# 4            95  ...          46                       60           59
# ..          ...  ...         ...                      ...          ...
# 145          92  ...          40                       60           52
# 146          98  ...          45                       60           49
# 147          99  ...          40                       60           50
# 148          76  ...          51                       60           36
# 149          83  ...          45                       60           46
#
#      Homework 10 - Max Points  Exam 1  Exam 1 - Max Points  Exam 2  \
# 0                          60      79                  100      63
# 1                          60      65                  100      63
# 2                          60      65                  100      78
# 3                          60      97                  100      97
# 4                          60      68                  100      95
# ..                        ...     ...                  ...     ...
# 145                        60      94                  100      74
# 146                        60      91                  100      67
# 147                        60      68                  100      93
# 148                        60      84                  100      91
# 149                        60      86                  100      62
#
#      Exam 2 - Max Points  Exam 3  Exam 3 - Max Points
# 0                    100      68                  100
# 1                    100      90                  100
# 2                    100      83                  100
# 3                    100      81                  100
# 4                    100      88                  100
# ..                   ...     ...                  ...
# 145                  100      68                  100
# 146                  100     100                  100
# 147                  100      69                  100
# 148                  100      95                  100
# 149                  100      90                  100
#
# [150 rows x 29 columns]

# %% [markdown]
# ### **Load the Quiz Files**

# %% [markdown]
# Load quiz grades (quiz_1_grades.csv, ..., quiz_5_grades.csv)

# %%
#load all the quizzes now, but i want it the dataframe to be indexed on emails, and return all quizzes corresponding to that email.
#for the expected output of this code, refer to the submissional pdf shared with you in whatsapp group.
quiz_1 = pd.read_csv('/content/quiz_1_grades (1) - quiz_1_grades (1).csv.xls')
quiz_2 = pd.read_csv('/content/quiz_2_grades - quiz_2_grades.csv.xls')
quiz_3 = pd.read_csv('/content/quiz_3_grades - quiz_3_grades.csv.xls')
quiz_4 = pd.read_csv('/content/quiz_4_grades - quiz_4_grades.csv.xls')
quiz_5 = pd.read_csv('/content/quiz_5_grades - quiz_5_grades.csv.xls')

# %% [markdown]
# Now, join the roster and the hw_exam_grades and store it in a df named '**final_df**' display first 5 rows.

# %%
hw_exam_grades.rename(columns={"SID": "NetID"}, inplace=True)

# %%
hw_exam_grades.set_index('NetID', inplace=True)
final_df = pd.merge(roster, hw_exam_grades, on='NetID')
final_df
# Out:
#                ID                     Name              Email Address  \
# NetID
# wxb12345  1234567       Barrera Jr., Woody  woody.barrera_jr@univ.edu
# mxl12345  2345678         Lambert, Malaika   malaika.lambert@univ.edu
# txj12345  3456789             Joyce, Traci       traci.joyce@univ.edu
# jgf12345  4567890       Flower, John Gregg   john.g.2.flower@univ.edu
# smj00936  8406082   Johnson, Stacy Michael     stacy.johnson@univ.edu
# ...           ...                      ...                        ...
# pmj37756  5227994       Johnson, Paul Mark      paul.johnson@univ.edu
# dsl24347  9804556  Lee, Danielle Stephanie      danielle.lee@univ.edu
# nxe44872  1783442          Edwards, Nicole    nicole.edwards@univ.edu
# bxr62103  6345758            Reyes, Bailey      bailey.reyes@univ.edu
# jxw53347  5566719             Walls, Joyce       joyce.walls@univ.edu
#
#           Section First Name Last Name  Homework 1  Homework 1 - Max Points  \
# NetID
# wxb12345        1      Woody   Barrera        55.0                       80
# mxl12345        2    Malaika   Lambert        63.0                       80
# txj12345        1      Traci     Joyce         NaN                       80
# jgf12345        3      Gregg    Flower        69.0                       80
# smj00936        2      Stacy   Johnson        74.0                       80
# ...           ...        ...       ...         ...                      ...
# pmj37756        3       Paul   Johnson        73.0                       80
# dsl24347        3   Danielle       Lee        69.0                       80
# nxe44872        3     Nicole   Edwards        62.0                       80
# bxr62103        2     Bailey     Reyes        53.0                       80
# jxw53347        1      Joyce     Walls        59.0                       80
#
#           Homework 2  Homework 2 - Max Points  ...  Homework 9  \
# NetID                                          ...
# wxb12345          62                       80  ...          45
# mxl12345          57                       80  ...          45
# txj12345          77                       80  ...          59
# jgf12345          52                       80  ...          42
# smj00936          55                       80  ...          59
# ...              ...                      ...  ...         ...
# pmj37756          50                       80  ...          40
# dsl24347          51                       80  ...          49
# nxe44872          76                       80  ...          58
# bxr62103          50                       80  ...          41
# jxw53347          77                       80  ...          40
#
#           Homework 9 - Max Points  Homework 10  Homework 10 - Max Points  \
# NetID
# wxb12345                       60           46                        60
# mxl12345                       60           37                        60
# txj12345                       60           53                        60
# jgf12345                       60           40                        60
# smj00936                       60           48                        60
# ...                           ...          ...                       ...
# pmj37756                       60           51                        60
# dsl24347                       60           57                        60
# nxe44872                       60           51                        60
# bxr62103                       60           46                        60
# jxw53347                       60           42                        60
#
#           Exam 1  Exam 1 - Max Points  Exam 2  Exam 2 - Max Points  Exam 3  \
# NetID
# wxb12345      86                  100      62                  100      90
# mxl12345      60                  100      91                  100      93
# txj12345     100                  100      84                  100      64
# jgf12345      72                  100      83                  100      77
# smj00936      96                  100      80                  100      86
# ...          ...                  ...     ...                  ...     ...
# pmj37756      84                  100      80                  100      94
# dsl24347      62                  100      70                  100      90
# nxe44872      89                  100      63                  100      65
# bxr62103      90                  100      72                  100      71
# jxw53347      69                  100      73                  100      91
#
#           Exam 3 - Max Points
# NetID
# wxb12345                  100
# mxl12345                  100
# txj12345                  100
# jgf12345                  100
# smj00936                  100
# ...                       ...
# pmj37756                  100
# dsl24347                  100
# nxe44872                  100
# bxr62103                  100
# jxw53347                  100
#
# [150 rows x 32 columns]

# %% [markdown]
# Also, display quiz **columns** and **indexes** in two seperate code blocks to make sure you get the sense of the data.

# %%
# INDEXES
print(quiz_1.index)
print(quiz_2.index)
print(quiz_3.index)
print(quiz_4.index)
print(quiz_5.index)

# %%
# COLUMNS
print("Quiz 01 Columns:", quiz_1.columns)
print("Quiz 02 Columns:", quiz_2.columns)
print("Quiz 03 Columns:", quiz_3.columns)
print("Quiz 04 Columns:", quiz_4.columns)
print("Quiz 05 Columns:", quiz_5.columns)

# %%
quiz_1.rename(columns={"Email": "Email Address" , "Grade" : "Grade1"}, inplace=True)
quiz_2.rename(columns={"Email": "Email Address" , "Grade" : "Grade2"}, inplace=True)
quiz_3.rename(columns={"Email": "Email Address" , "Grade" : "Grade3"}, inplace=True)
quiz_4.rename(columns={"Email": "Email Address" , "Grade" : "Grade4"}, inplace=True)
quiz_5.rename(columns={"Email": "Email Address" , "Grade" : "Grade5"}, inplace=True)
quiz_1.drop(["Last Name", "First Name"] , axis=1 , inplace=True)
quiz_2.drop(["Last Name", "First Name"] , axis=1 , inplace=True)
quiz_3.drop(["Last Name", "First Name"] , axis=1 , inplace=True)
quiz_4.drop(["Last Name", "First Name"] , axis=1 , inplace=True)
quiz_5.drop(["Last Name", "First Name"] , axis=1 , inplace=True)
# Out:
#             Email Address  Grade5
# 0  rachel.dennis@univ.edu      11
# 1  courtney.wolf@univ.edu       9

# %% [markdown]
# ### **Merging the Grade DataFrame**

# %%
#now merge the final_df and quiz grades, on EMAIL ADDRESS and overwrite it in final_df variable

#fill empty values with 0 as well

final_df = pd.merge(final_df , quiz_1 , on='Email Address', how='inner')
final_df = pd.merge(final_df , quiz_2 , on='Email Address', how='inner')
final_df = pd.merge(final_df , quiz_3 , on='Email Address', how='inner')
final_df = pd.merge(final_df , quiz_4 , on='Email Address', how='inner')
final_df = pd.merge(final_df , quiz_5 , on='Email Address', how='inner')
final_df.head(1)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
#
#    Homework 2 - Max Points  ...  Exam 1 - Max Points  Exam 2  \
# 0                       80  ...                  100      62
#
#    Exam 2 - Max Points  Exam 3  Exam 3 - Max Points  Grade1  Grade2  Grade3  \
# 0                  100      90                  100       4      10      11
#
#    Grade4  Grade5
# 0       7      10
#
# [1 rows x 37 columns]

# %% [markdown]
# ### **Calculate Grades with Pandas DataFrame**

# %% [markdown]
# ### Exam Grades

# %% [markdown]
# Now, I want you to calculate the percentage of all 3 exams and then have it display at the end of the final_df

# %%
#to find the percentage:   Exam 1 / Exam 1 max points.
#Hint: you can use fstrings and loops for it

Exams = ['Exam 1','Exam 2','Exam 3']
Max = ['Exam 1 - Max Points','Exam 2 - Max Points','Exam 3 - Max Points']
for e,m in zip(Exams, Max):
  final_df[f'Percentage {e}'] = (final_df[e]) / final_df[m]
final_df.head(2)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Exam 3  Exam 3 - Max Points  Grade1  Grade2  \
# 0                       80  ...      90                  100       4      10
# 1                       80  ...      93                  100       8      10
#
#    Grade3  Grade4  Grade5  Percentage Exam 1  Percentage Exam 2  \
# 0      11       7      10               0.86               0.62
# 1      10      13       6               0.60               0.91
#
#    Percentage Exam 3
# 0               0.90
# 1               0.93
#
# [2 rows x 40 columns]

# %% [markdown]
# ### Homework Grades

# %% [markdown]
# **Question 1: Identifying Homework Columns**

# %%
#Identify and separate the columns representing homework scores and their respective maximum points.
hw_part = final_df.loc[:, final_df.columns.map(lambda x: 'Homework' in x)]
hw_part.head(3)
# Out:
#    Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# 0        55.0                       80          62                       80
# 1        63.0                       80          57                       80
# 2         NaN                       80          77                       80
#
#    Homework 3  Homework 3 - Max Points  Homework 4  Homework 4 - Max Points  \
# 0          73                       80          83                      100
# 1          78                       80          83                      100
# 2          58                       80          91                      100
#
#    Homework 5  Homework 5 - Max Points  Homework 6  Homework 6 - Max Points  \
# 0          68                       70          87                       90
# 1          61                       70          88                       90
# 2          66                       70          78                       90
#
#    Homework 7  Homework 7 - Max Points  Homework 8  Homework 8 - Max Points  \
# 0          36                       50          43                       70
# 1          42                       50          58                       70
# 2          30                       50          69                       70
#
#    Homework 9  Homework 9 - Max Points  Homework 10  Homework 10 - Max Points
# 0          45                       60           46                        60
# 1          45                       60           37                        60
# 2          59                       60           53                        60

# %% [markdown]
# **Question 2: Calculating Homework Score by Total Method**

# %%
#Calculate the homework scores by summing the actual scores and dividing by the total possible points.
# homework_score = hw_part.iloc[:, ::2].sum() / hw_part.iloc[:, 1::2].sum()

#sum_of_actual_score = hw_part.iloc[:, ::2].sum(axis=1)
#total_possible_points = hw_part.iloc[:, 1::2].sum(axis=1)

homework_scores = final_df.filter(regex=r"^Homework \d\d?$", axis=1)
homework_max_points = final_df.filter(regex=r"^Homework \d\d? -", axis=1)

# %% [markdown]
# **Question 3: Storing Homework Score by Total Method**

# %%
#Add the calculated total homework scores to the DataFrame.
final_df['Homework Score'] = homework_scores.sum(axis=1) / homework_max_points.sum(axis=1)
final_df.head(2)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Exam 3 - Max Points  Grade1  Grade2  Grade3  \
# 0                       80  ...                  100       4      10      11
# 1                       80  ...                  100       8      10      10
#
#    Grade4  Grade5  Percentage Exam 1  Percentage Exam 2  Percentage Exam 3  \
# 0       7      10               0.86               0.62               0.90
# 1      13       6               0.60               0.91               0.93
#
#    Homework Score
# 0        0.808108
# 1        0.827027
#
# [2 rows x 41 columns]

# %% [markdown]
# **Question 4: Preparing Data for Average Calculation**

# %%
#Prepare the maximum points data to align with the actual scores for element-wise division.
final_df.head(2)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Exam 3 - Max Points  Grade1  Grade2  Grade3  \
# 0                       80  ...                  100       4      10      11
# 1                       80  ...                  100       8      10      10
#
#    Grade4  Grade5  Percentage Exam 1  Percentage Exam 2  Percentage Exam 3  \
# 0       7      10               0.86               0.62               0.90
# 1      13       6               0.60               0.91               0.93
#
#    Homework Score
# 0        0.808108
# 1        0.827027
#
# [2 rows x 41 columns]

# %% [markdown]
# **Question 5: Calculating Homework Score by Average Method**

# %%
#Calculate the average homework scores by dividing each actual score by its corresponding maximum points, summing these ratios, and then dividing by the number of assignments.
#homework_scores = final_df.filter(regex=r"^Homework \d\d?$", axis=1)
#homework_max_points = final_df.filter(regex=r"^Homework \d\d? -", axis=1)
hw_max_renamed = homework_max_points.set_axis(homework_scores.columns, axis=1)
average_hw_scores = (homework_scores / hw_max_renamed).sum(axis=1)

# %% [markdown]
# **Question 6: Storing Homework Score by Average Method**

# %%
#Add the calculated average homework scores to the DataFrame.
final_df['HW by Average'] = average_hw_scores / homework_scores.shape[1]
final_df.head(2)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Grade1  Grade2  Grade3  Grade4  Grade5  \
# 0                       80  ...       4      10      11       7      10
# 1                       80  ...       8      10      10      13       6
#
#    Percentage Exam 1  Percentage Exam 2  Percentage Exam 3  Homework Score  \
# 0               0.86               0.62               0.90        0.808108
# 1               0.60               0.91               0.93        0.827027
#
#    HW by Average
# 0       0.799405
# 1       0.818944
#
# [2 rows x 42 columns]

# %% [markdown]
# **Question 7: Determining the Final Homework Score**

# %%
#Determine the final homework score for each student by taking the maximum value between the total and average methods.
final_df['HW by Total'] = final_df[['Homework Score','HW by Average']].max(axis=1)
final_df.head(2)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Grade2  Grade3  Grade4  Grade5  \
# 0                       80  ...      10      11       7      10
# 1                       80  ...      10      10      13       6
#
#    Percentage Exam 1  Percentage Exam 2  Percentage Exam 3  Homework Score  \
# 0               0.86               0.62               0.90        0.808108
# 1               0.60               0.91               0.93        0.827027
#
#    HW by Average  HW by Total
# 0       0.799405     0.808108
# 1       0.818944     0.827027
#
# [2 rows x 43 columns]

# %% [markdown]
# For the output, you may refer to the output refered in the Submission Book.

# %% [markdown]
# ## Quiz Grades
#
# If you used any other method instead of regex to filter the columns, it will result in appropriate points deduction.

# %%
#Filter the columns representing quiz scores using regex.
quiz_scores = final_df.filter(regex=r"^Grade\d$", axis=1)
quiz_scores.head(2)
# Out:
#    Grade1  Grade2  Grade3  Grade4  Grade5
# 0       4      10      11       7      10
# 1       8      10      10      13       6

# %% [markdown]
# 1. Count the number of quizzes.
# 2. Define the maximum possible points for each quiz.
# 3. Compute the quiz score using the total method.
# 4. Compute the quiz score using the average method.
# 5. Determine the final quiz score by taking the maximum of the two methods.
# 6. Display the DataFrame to check the results

# %%
#Expected Output: The DataFrame should contain an additional column 'Quiz Score' showing the final quiz score for each student, calculated as the maximum value between the total and average methods.
quiz_count = quiz_scores.shape[1]
print('There are',quiz_count,'number of quizzes.')
max_quiz_scores = quiz_scores.max()

sum_of_quiz_scores = quiz_scores.sum(axis=1)
sum_of_quiz_max = max_quiz_scores.sum()
final_df["Quiz Total"] = sum_of_quiz_scores / sum_of_quiz_max

average_quiz_scores = (quiz_scores / max_quiz_scores).sum(axis=1)
final_df["Quiz Average"] = average_quiz_scores / quiz_scores.shape[1]

final_df["Quiz Score"] = final_df[
    ["Quiz Total", "Quiz Average"]
].max(axis=1)
final_df
# Out:
# There are 5 number of quizzes.
#           ID                     Name              Email Address  Section  \
# 0    1234567       Barrera Jr., Woody  woody.barrera_jr@univ.edu        1
# 1    2345678         Lambert, Malaika   malaika.lambert@univ.edu        2
# 2    3456789             Joyce, Traci       traci.joyce@univ.edu        1
# 3    4567890       Flower, John Gregg   john.g.2.flower@univ.edu        3
# 4    8406082   Johnson, Stacy Michael     stacy.johnson@univ.edu        2
# ..       ...                      ...                        ...      ...
# 145  5227994       Johnson, Paul Mark      paul.johnson@univ.edu        3
# 146  9804556  Lee, Danielle Stephanie      danielle.lee@univ.edu        3
# 147  1783442          Edwards, Nicole    nicole.edwards@univ.edu        3
# 148  6345758            Reyes, Bailey      bailey.reyes@univ.edu        2
# 149  5566719             Walls, Joyce       joyce.walls@univ.edu        1
#
#     First Name Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0        Woody   Barrera        55.0                       80          62
# 1      Malaika   Lambert        63.0                       80          57
# 2        Traci     Joyce         NaN                       80          77
# 3        Gregg    Flower        69.0                       80          52
# 4        Stacy   Johnson        74.0                       80          55
# ..         ...       ...         ...                      ...         ...
# 145       Paul   Johnson        73.0                       80          50
# 146   Danielle       Lee        69.0                       80          51
# 147     Nicole   Edwards        62.0                       80          76
# 148     Bailey     Reyes        53.0                       80          50
# 149      Joyce     Walls        59.0                       80          77
#
#      Homework 2 - Max Points  ...  Grade5  Percentage Exam 1  \
# 0                         80  ...      10               0.86
# 1                         80  ...       6               0.60
# 2                         80  ...       4               1.00
# 3                         80  ...       5               0.72
# 4                         80  ...       7               0.96
# ..                       ...  ...     ...                ...
# 145                       80  ...      10               0.84
# 146                       80  ...       7               0.62
# 147                       80  ...      10               0.89
# 148                       80  ...       7               0.90
# 149                       80  ...      12               0.69
#
#      Percentage Exam 2  Percentage Exam 3  Homework Score  HW by Average  \
# 0                 0.62               0.90        0.808108       0.799405
# 1                 0.91               0.93        0.827027       0.818944
# 2                 0.84               0.64        0.785135       0.785940
# 3                 0.83               0.77        0.770270       0.765710
# 4                 0.80               0.86        0.782432       0.787742
# ..                 ...                ...             ...            ...
# 145               0.80               0.94        0.735135       0.733325
# 146               0.70               0.90        0.822973       0.816865
# 147               0.63               0.65        0.839189       0.841175
# 148               0.72               0.71        0.779730       0.773690
# 149               0.73               0.91        0.751351       0.745171
#
#      HW by Total  Quiz Total  Quiz Average  Quiz Score
# 0       0.808108    0.608696      0.602139    0.608696
# 1       0.827027    0.681159      0.682149    0.682149
# 2       0.785940    0.594203      0.585399    0.594203
# 3       0.770270    0.608696      0.615286    0.615286
# 4       0.787742    0.652174      0.641836    0.652174
# ..           ...         ...           ...         ...
# 145     0.735135    0.782609      0.798177    0.798177
# 146     0.822973    0.623188      0.619682    0.623188
# 147     0.841175    0.768116      0.785796    0.785796
# 148     0.779730    0.797101      0.784199    0.797101
# 149     0.751351    0.637681      0.667701    0.667701
#
# [150 rows x 46 columns]

# %% [markdown]
# ## Group the data to calculate final scores!

# %%
# weights = pd.Series(
#     {
#         "Exam 1 Score": 0.05,
#         "Exam 2 Score": 0.10,
#         "Exam 3 Score": 0.15,
#         "Quiz Score": 0.30,
#         "Homework Score": 0.40,
#     }
# )

weights = pd.Series(
    {
        "Percentage Exam 1": 0.05,
        "Percentage Exam 2": 0.10,
        "Percentage Exam 3": 0.15,
        "Quiz Total": 0.30,
        "Homework Score": 0.40,
    }
)

final_df[["Percentage Exam 1", "Percentage Exam 2", "Percentage Exam 3", "Quiz Total", "Homework Score"]].head()
final_df.head()
# Out:
#         ID                    Name              Email Address  Section  \
# 0  1234567      Barrera Jr., Woody  woody.barrera_jr@univ.edu        1
# 1  2345678        Lambert, Malaika   malaika.lambert@univ.edu        2
# 2  3456789            Joyce, Traci       traci.joyce@univ.edu        1
# 3  4567890      Flower, John Gregg   john.g.2.flower@univ.edu        3
# 4  8406082  Johnson, Stacy Michael     stacy.johnson@univ.edu        2
#
#   First Name Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0      Woody   Barrera        55.0                       80          62
# 1    Malaika   Lambert        63.0                       80          57
# 2      Traci     Joyce         NaN                       80          77
# 3      Gregg    Flower        69.0                       80          52
# 4      Stacy   Johnson        74.0                       80          55
#
#    Homework 2 - Max Points  ...  Grade5  Percentage Exam 1  Percentage Exam 2  \
# 0                       80  ...      10               0.86               0.62
# 1                       80  ...       6               0.60               0.91
# 2                       80  ...       4               1.00               0.84
# 3                       80  ...       5               0.72               0.83
# 4                       80  ...       7               0.96               0.80
#
#    Percentage Exam 3  Homework Score  HW by Average  HW by Total  Quiz Total  \
# 0               0.90        0.808108       0.799405     0.808108    0.608696
# 1               0.93        0.827027       0.818944     0.827027    0.681159
# 2               0.64        0.785135       0.785940     0.785940    0.594203
# 3               0.77        0.770270       0.765710     0.770270    0.608696
# 4               0.86        0.782432       0.787742     0.787742    0.652174
#
#    Quiz Average  Quiz Score
# 0      0.602139    0.608696
# 1      0.682149    0.682149
# 2      0.585399    0.594203
# 3      0.615286    0.615286
# 4      0.641836    0.652174
#
# [5 rows x 46 columns]

# %% [markdown]
# 1. Define the weights for each component.
# 2. Calculate the final score by applying the weights to each component and summing the results.
# 3. Calculate the ceiling score by rounding up the final score multiplied by 100.
# 4. Define a function to convert numeric scores to letter grades based on standard thresholds.
# 5. Map the ceiling scores to letter grades.
# 6. Store the letter grades as a categorical column in the DataFrame.
# 7. Display the final letter grades.

# %%
#For Expected output, refer to the submissional pdf.
final_df["Final Score"] = (final_df[weights.index] * weights).sum(axis=1)
final_df["Ceiling Score"] = np.ceil(final_df["Final Score"] * 100)
final_df.head(1)
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
#
#    Homework 2 - Max Points  ...  Percentage Exam 2  Percentage Exam 3  \
# 0                       80  ...               0.62                0.9
#
#    Homework Score  HW by Average  HW by Total  Quiz Total  Quiz Average  \
# 0        0.808108       0.799405     0.808108    0.608696      0.602139
#
#    Quiz Score  Final Score  Ceiling Score
# 0    0.608696     0.745852           75.0
#
# [1 rows x 48 columns]

# %%
grades = {90: "A",80: "B",70: "C",60: "D",0: "F",}
def assign_grades(value):
    for key, letter in grades.items():
        if value >= key:
            return letter
grade = final_df["Ceiling Score"].map(assign_grades)

# final_results = final_df[["NetID", "Last Name", "First Name", "Email Address", "Ceiling Score", "Final Grade"]].head()
# Out:
#         ID                Name              Email Address  Section First Name  \
# 0  1234567  Barrera Jr., Woody  woody.barrera_jr@univ.edu        1      Woody
# 1  2345678    Lambert, Malaika   malaika.lambert@univ.edu        2    Malaika
#
#   Last Name  Homework 1  Homework 1 - Max Points  Homework 2  \
# 0   Barrera        55.0                       80          62
# 1   Lambert        63.0                       80          57
#
#    Homework 2 - Max Points  ...  Percentage Exam 3  Homework Score  \
# 0                       80  ...               0.90        0.808108
# 1                       80  ...               0.93        0.827027
#
#    HW by Average  HW by Total  Quiz Total  Quiz Average  Quiz Score  \
# 0       0.799405     0.808108    0.608696      0.602139    0.608696
# 1       0.818944     0.827027    0.681159      0.682149    0.682149
#
#    Final Score  Ceiling Score  Final Grade
# 0     0.745852           75.0            C
# 1     0.795659           80.0            B
#
# [2 rows x 49 columns]

# %%
final = pd.merge(final_df, netid, on='ID')
final_results = final[['NetID','Last Name','First Name','Email Address','Ceiling Score','Final Grade']]
final_results.head()
# Out:
#       NetID Last Name First Name              Email Address  Ceiling Score  \
# 0  WXB12345   Barrera      Woody  woody.barrera_jr@univ.edu           75.0
# 1  MXL12345   Lambert    Malaika   malaika.lambert@univ.edu           80.0
# 2  TXJ12345     Joyce      Traci       traci.joyce@univ.edu           73.0
# 3  JGF12345    Flower      Gregg   john.g.2.flower@univ.edu           73.0
# 4  SMJ00936   Johnson      Stacy     stacy.johnson@univ.edu           77.0
#
#   Final Grade
# 0           C
# 1           B
# 2           C
# 3           C
# 4           C

# %% [markdown]
# ### Now, you have to write the data back to CSV.

# %%
#For the expected output, refer to the submissional pdf.

# %%
final_results.to_csv("final_results.csv", index=False)
